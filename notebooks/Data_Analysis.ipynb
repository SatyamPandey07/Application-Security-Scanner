# %% [markdown]
# # Sentinel Data Analysis\n\nThis notebook can be used for querying the backend database to visualize security trends, analyze findings, or test out new metrics.

# %%
import sqlite3\nimport pandas as pd\n\n# Example: connecting to the Sentinel database\n# Adjust the connection string as needed for your local postgres setup or sqlite test db.\n# conn = sqlite3.connect('../backend/sentinel_dev.db')\n# df = pd.read_sql_query(\"SELECT * FROM findings LIMIT 5\", conn)\n# df.head()
